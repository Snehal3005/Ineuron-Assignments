# %% [markdown]
# 1. What exactly is []?
#
#      [] is an empty list, contains no items.
#
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
#
#     spam[2] = 'hello'
#
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
#      ‘d’
#
# 4. What is the value of spam[-1]?
#
#      ‘-d’
#
# 5. What is the value of spam[:2]?
#
#      [‘a’ , ‘b’]
#
#
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
#
# 6. What is the value of bacon.index('cat')?
#
#   1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
#     bacon = [3.14, 'cat', 11, 'cat', True, 99]
#
# 8. How does bacon.remove('cat') change the look of the list meaning in bacon?
#
#     bacon = [3.14, 11, 'cat', True, 99]
#
#
#  9. What are the list concatenation and list replication operators?
#
#     + is list concatenation operator
#
#     * is list replication opeartor
#
#
# 10. What is difference between the list methods append() and insert()?
#
#     append() method adds element to the end of list
#
#     insert() method inserts a element before a specified index
#
#
# 11. What are the two methods for removing items from a list?
#
#     remove() and pop() methods for removing items from a list.
#
#
# 12. Describe how list values and string values are identical.
#
#     Both list and strings have same indexing, slicing, concatenation, copying. Iteration through list and string
#     is also similar.
#
#
# 13. What's the difference between tuples and lists?
#
#     Tuples are immutable i.e. elements can not be added, removed, updated. Tuples are represented as elments enclosed
#     in ( )
#
#     whereas lists are mutable i.e.elements can be added, removed, updated. Lists are represented as elemnts enclosed in [ ]
#
#
# 14. How do you type a tuple value that only contains the integer 42?
#
#     tuple1 = (42,)
#
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
#
#     tuple() function give list value's tuple form.
#
#     e.g.

# %%
list1 = [1,2,3,4,5]
    
tuple(list1)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# list() function give tuple value's list form
#
# e.g.

# %%
tuple1 = (1,2,3,4,5)
    
list(tuple1)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
#
#     These variables contains references to the respective values of list.
#
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
#     A copy.copy() means constructing a new collection object and then populating it with references to the objects found in the original. Here, a reference of object is copied in other object. It means that any changes made to a copy of object do reflect in the original object.
#
#        e.g.

# %%
import copy

old_list = [1,2,[3,4],5,7]
print('Old list before copying...', old_list)

new_list = copy.copy(old_list)

new_list[2][1] = 6

print('Old list after copying...', old_list)
print('New list after copying...', new_list)
# Out:
# Old list before copying... [1, 2, [3, 4], 5, 7]
# Old list after copying... [1, 2, [3, 6], 5, 7]
# New list after copying... [1, 2, [3, 6], 5, 7]

# %% [markdown]
# A copy.deepcopy() constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.In this, rather than just copying the address of the compound objects, it simply makes a full copy of all the list’s elements (simple and compound objects) of the original list and allocates a different memory address for the new list and then assigns them the copied elements.
#
# e.g.

# %%
import copy

old_list = [1,2,[3,4],5,7]
print('Old list before copying...', old_list)

new_list = copy.deepcopy(old_list)

new_list[2][1] = 6

print('Old list after copying...', old_list)
print('New list after copying...', new_list)
# Out:
# Old list before copying... [1, 2, [3, 4], 5, 7]
# Old list after copying... [1, 2, [3, 4], 5, 7]
# New list after copying... [1, 2, [3, 6], 5, 7]

# %% [markdown]
# for both copy and deepcopy it is apllicable to only compound objects i.e. objects within object.
