# %% [markdown]
# 1. Write a Python program to find words which are greater than given length k?

# %%
k = int(input('Enter length::'))

n = int(input('Enter number of words you would like to enter ::'))

words = []

while n > 0:
    words.append(input('Enter a word::'))
    n -= 1

new_words = [] 

for word in words:
    if len(word) > k:
        new_words.append(word)
        
print(f'{new_words} are the words with length greater than {k}')
# Out:
# Enter length::2
# Enter number of words you would like to enter ::4
# Enter a word::ab
# Enter a word::abc
# Enter a word::abcd
# Enter a word::abcde
# ['abc', 'abcd', 'abcde'] are the words with length greater than 2

# %% [markdown]
# 2. Write a Python program for removing i-th character from a string?

# %%
s = input('Enter string::')

i = int(input('Enter index of character you would like to remove::'))

tuple_of_partitioned_strings = s.partition(s[i])
new_string = str(tuple_of_partitioned_strings[0] + tuple_of_partitioned_strings[2])

print(f'String after removing index {i} character is::',new_string)
# Out:
# Enter string::Ineuron has great instructors
# Enter index of character you would like to remove::10
# String after removing index 10 character is:: Ineuron ha great instructors

# %% [markdown]
# 3. Write a Python program to split and join a string?

# %%
s = 'Write a Python program to split and join a string'

s.split()

'*'.join(s)
# Out:
# 'W*r*i*t*e* *a* *P*y*t*h*o*n* *p*r*o*g*r*a*m* *t*o* *s*p*l*i*t* *a*n*d* *j*o*i*n* *a* *s*t*r*i*n*g'

# %% [markdown]
# 4. Write a Python to check if a given string is binary string or not?

# %%
s = input('Enter string::')

for char in s:
    if char != '0' and char != '1':
        print(f'{s} is not binary')
        break
else:
    print(f'{s} is binary')
# Out:
# Enter string::0101010101010111111111111100000000
# 0101010101010111111111111100000000 is binary

# %% [markdown]
# 5. Write a Python program to find uncommon words from two Strings?

# %%
s1 = input('Enter string 1 ::')
s2 = input('Enter string 2 ::')

s1 = set(s1.split())
s2 = set(s2.split())

s1.symmetric_difference(s2)
# Out:
# Enter string 1 ::My name is Snehal and I am ME Computers
# Enter string 2 ::My name is Pankaj and I am ME Electronics
# {'Computers', 'Electronics', 'Pankaj', 'Snehal'}

# %% [markdown]
# 6. Write a Python to find all duplicate characters in string?

# %%
s = input('Enter a sting::')
char_list = set()
for char in s:
    if s.count(char) > 1:
         char_list.add(char)
        
print('Duplicate characters in string are::',char_list)
# Out:
# Enter a sting::Write a Python to find all duplicate characters in string
# Duplicate characters in string are:: {'o', 'r', 'c', 'h', 't', 'l', 'a', 's', 'n', ' ', 'd', 'i', 'e'}

# %% [markdown]
# 7. Write a Python Program to check if a string contains any special character?

# %%
symbols = {'`','~','!','@','#','$','%','^','&','*','(',')','_','-','+','=','{','[','}','}','|',':',';','"','<',',','>','.','?','/'}
s = input('Enter a sting::')
flag = 0
           
for char in s:
    if char in symbols:
        flag = 1

if flag == 1:
    print('String contains special character')
else:
    print('String does not contain special character')
# Out:
# Enter a sting::Allow the naming of a PRIMARY KEY constraint, and for defining a PRIMARY KEY constraint on multiple columns, use the SQL query:
# String contains special character
