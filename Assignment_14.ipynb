# %% [markdown]
# 1. What does RGBA stand for?
#
#     An RGBA value is a tuple of 4 integers, each ranging from 0 to 255. The four integers correspond to the amount of red, green, blue, and alpha (transparency) in the color.
#
#
# 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image, ImageColor

img = Image.open('ILTQq.png')
pixels = img.convert('RGBA')
pix_val = list(pixels.getdata())

pix_val_flat = [x for sets in pix_val for x in sets]

#print(pix_val_flat)

# %% [markdown]
# 3. What is a box tuple, and how does it work?
#
#     A box tuple is a tuple value of four integers: the left edge x-coordinate, the top edge y-coordinate, the width, and the height, respectively.
#
#
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
Image.open('ILTQq.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x479 at 0x1D399D7A280>

# %% [markdown]
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
img1 = Image.open('ILTQq.png')

print(img1.size)

crop_image = img.crop((200,0,300,100))
                      
crop_image
# Out:
# (400, 479)
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x1D399D7F820>

# %% [markdown]
# 6. After making changes to an Image object, how could you save it as an image file?

# %%
crop_image.save('Cropped_img.png')

# %% [markdown]
# 7. What module contains Pillow’s shape-drawing code?
#
#     ImageDraw module contains shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function.
#
#
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
#
#     The ImageDraw module contains code to draw on images.
#
#     ImageDraw module can be imported from PIL(pillow)

# %%
import math
from PIL import Image, ImageDraw
  
w, h = 220, 190
shape = [(40, 40), (w - 10, h - 10)]
  
# creating new Image object
img = Image.new("RGB", (w, h))
  
# create rectangle image
img1 = ImageDraw.Draw(img)  
img1.rectangle(shape, fill ="#ffff33", outline ="red")
img.show()
